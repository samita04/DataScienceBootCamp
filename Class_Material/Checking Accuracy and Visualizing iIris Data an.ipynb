# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,confusion_matrix

# %%
# !pip install --upgrade mlxtend

# %%
iris=load_iris()
X=iris.data
y=iris.target
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.3,random_state=52)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn import datasets
import numpy as np

# Initializing Classifiers
clf1 = LogisticRegression(random_state=1,
                          solver='newton-cg',
                          multi_class='multinomial')
clf2 = RandomForestClassifier(random_state=1, n_estimators=100)
clf3 = GaussianNB()
clf4 = SVC(gamma='auto')
clf5 = KNeighborsClassifier(n_neighbors=3)
clf6 = DecisionTreeClassifier()

# Loading some example data
iris = datasets.load_iris()
X = iris.data[:, [0,2]]
y = iris.target

# %%
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions
import matplotlib.gridspec as gridspec
import itertools
gs = gridspec.GridSpec(2, 2)

fig = plt.figure(figsize=(10,8))

labels = ['Logistic Regression', 'Random Forest', 'Naive Bayes', 'SVM', 'KNeighbors','Decision Tree']
for clf, lab, grd in zip([clf1, clf2, clf3, clf4, clf5, clf6],
                         labels, itertools.product([0, 1], repeat=3)):

    clf.fit(X, y)
    ax = plt.subplot(gs[grd[0],grd[1]])
    fig = plot_decision_regions(X=X, y=y, clf=clf, legend=2)
    plt.title(lab)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-c63ec347d7fc> in <cell line: 11>()
#      13
#      14     clf.fit(X, y)
# ---> 15     ax = plt.subplot(gs[grd[0],grd[1]], nrows=2, ncols=3)
#      16     fig = plot_decision_regions(X=X, y=y, clf=clf, legend=2)
#      17     plt.title(lab)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1315     # Check for nrows and ncols, which are not valid subplot args:
#    1316     if 'nrows' in kwargs or 'ncols' in kwargs:
# -> 1317         raise TypeError("subplot() got an unexpected keyword argument 'ncols' "
#    1318                         "and/or 'nrows'.  Did you intend to call subplots()?")
#    1319
#
# TypeError: subplot() got an unexpected keyword argument 'ncols' and/or 'nrows'.  Did you intend to call subplots()?

# %% [markdown]
# # ***K Nearest Neighbor***

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, y_train)
Y_pred = knn.predict(X_test)
accuracy_knn=round(accuracy_score(y_test,Y_pred)* 100, 2)
acc_knn = round(knn.score(X_train, y_train) * 100, 2)

cm = confusion_matrix(y_test, Y_pred)
accuracy = accuracy_score(y_test,Y_pred)
precision =precision_score(y_test, Y_pred,average='micro')
recall =  recall_score(y_test, Y_pred,average='micro')
f1 = f1_score(y_test,Y_pred,average='micro')
print('Confusion matrix for KNN\n',cm)
print('accuracy_KNN : %.3f' %accuracy)
print('precision_KNN : %.3f' %precision)
print('recall_KNN: %.3f' %recall)
# Out:
# Confusion matrix for KNN
#  [[11  0  0]
#  [ 0 14  3]
#  [ 0  0 17]]
# accuracy_KNN : 0.933
# precision_KNN : 0.933
# recall_KNN: 0.933

# %%
import matplotlib.pyplot as plt
import itertools
from mlxtend.plotting import plot_decision_regions
fig = plt.figure(figsize=(10, 8))
labels = ['KNN']
knn_Classifier=KNeighborsClassifier(n_neighbors=3)
knn_Classifier.fit(X[:,[0,2]],y)
fig = plot_decision_regions(X=X[:,[0,2]], y=y,clf=knn_Classifier, legend=2)
plt.title(labels[0])

plt.show()

# %% [markdown]
# # ***Gaussian Naive Bayes***

# %%
gaussian = GaussianNB()
gaussian.fit(X_train, y_train)
Y_pred = gaussian.predict(X_test)
accuracy_nb=round(accuracy_score(y_test,Y_pred)* 100, 2)
acc_gaussian = round(gaussian.score(X_train, y_train) * 100, 2)

cm = confusion_matrix(y_test, Y_pred)
accuracy = accuracy_score(y_test,Y_pred)
precision =precision_score(y_test, Y_pred,average='micro')
recall =  recall_score(y_test, Y_pred,average='micro')
f1 = f1_score(y_test,Y_pred,average='micro')
print('Confusion matrix for Naive Bayes\n',cm)
print('accuracy_Naive Bayes: %.3f' %accuracy)
print('precision_Naive Bayes: %.3f' %precision)
print('recall_Naive Bayes: %.3f' %recall)
print('f1-score_Naive Bayes : %.3f' %f1)
# Out:
# Confusion matrix for Naive Bayes
#  [[11  0  0]
#  [ 0 13  4]
#  [ 0  0 17]]
# accuracy_Naive Bayes: 0.911
# precision_Naive Bayes: 0.911
# recall_Naive Bayes: 0.911
# f1-score_Naive Bayes : 0.911

# %%
import matplotlib.pyplot as plt
import itertools
from mlxtend.plotting import plot_decision_regions
fig = plt.figure(figsize=(10, 8))
labels = ['GaussianNB']
NB_Classifier=GaussianNB()
NB_Classifier.fit(X[:,[0,2]],y)
fig = plot_decision_regions(X=X[:,[0,2]], y=y,clf=NB_Classifier, legend=2)
plt.title(labels[0])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-f688e603b638> in <cell line: 7>()
#       5 labels = ['GaussianNB']
#       6 NB_Classifier=GaussianNB()
# ----> 7 NB_Classifier.fit(X[:,[0,2]],y)
#       8 fig = plot_decision_regions(X=X[:,[0,2]], y=y,clf=NB_Classifier, legend=2)
#       9 plt.title(labels[0])
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %% [markdown]
# # ***Linear Support Vector Machine***

# %%
from sklearn.svm import SVC, LinearSVC
linear_svc = LinearSVC(max_iter=4000)
linear_svc.fit(X_train, y_train)
Y_pred = linear_svc.predict(X_test)
accuracy_svc=round(accuracy_score(y_test,Y_pred)* 100, 2)
acc_linear_svc = round(linear_svc.score(X_train, y_train) * 100, 2)

cm = confusion_matrix(y_test, Y_pred)
accuracy = accuracy_score(y_test,Y_pred)
precision =precision_score(y_test, Y_pred,average='micro')
recall =  recall_score(y_test, Y_pred,average='micro')
f1 = f1_score(y_test,Y_pred,average='micro')
print('Confusion matrix for SVC\n',cm)
print('accuracy_SVC: %.3f' %accuracy)
print('precision_SVC: %.3f' %precision)
print('recall_SVC: %.3f' %recall)
print('f1-score_SVC : %.3f' %f1)
# Out:
# Confusion matrix for SVC
#  [[11  0  0]
#  [ 0 13  4]
#  [ 0  0 17]]
# accuracy_SVC: 0.911
# precision_SVC: 0.911
# recall_SVC: 0.911
# f1-score_SVC : 0.911

# %%
import matplotlib.pyplot as plt
import itertools
from mlxtend.plotting import plot_decision_regions
fig = plt.figure(figsize=(10, 8))
labels = ['SVM']
SVM_Classifier=SVC(gamma='auto')
SVM_Classifier.fit(X[:,[0,2]],y)
fig = plot_decision_regions(X=X[:,[0,2]], y=y,clf=SVM_Classifier, legend=2)
plt.title(labels[0])

plt.show()

# %% [markdown]
# # ***Decision Tree***

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, y_train)
Y_pred = decision_tree.predict(X_test)
accuracy_dt=round(accuracy_score(y_test,Y_pred)* 100, 2)
acc_decision_tree = round(decision_tree.score(X_train, y_train) * 100, 2)

cm = confusion_matrix(y_test, Y_pred)
accuracy = accuracy_score(y_test,Y_pred)
precision =precision_score(y_test, Y_pred,average='micro')
recall =  recall_score(y_test, Y_pred,average='micro')
f1 = f1_score(y_test,Y_pred,average='micro')
print('Confusion matrix for DecisionTree\n',cm)
print('accuracy_DecisionTree: %.3f' %accuracy)
print('precision_DecisionTree: %.3f' %precision)
print('recall_DecisionTree: %.3f' %recall)
print('f1-score_DecisionTree : %.3f' %f1)
# Out:
# Confusion matrix for DecisionTree
#  [[11  0  0]
#  [ 0 14  3]
#  [ 0  0 17]]
# accuracy_DecisionTree: 0.933
# precision_DecisionTree: 0.933
# recall_DecisionTree: 0.933
# f1-score_DecisionTree : 0.933

# %%
import matplotlib.pyplot as plt
import itertools
from mlxtend.plotting import plot_decision_regions
fig = plt.figure(figsize=(10, 8))
labels = ['SVC']
DT_Classifier = DecisionTreeClassifier()
DT_Classifier.fit(X[:,[0,2]],y)
fig = plot_decision_regions(X=X[:,[0,2]], y=y,clf=DT_Classifier, legend=2)
plt.title(labels[0])

plt.show()

# %% [markdown]
# # ***Random Forest***

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, y_train)
Y_prediction = random_forest.predict(X_test)
accuracy_rf=round(accuracy_score(y_test,Y_prediction)* 100, 2)
acc_random_forest = round(random_forest.score(X_train, y_train) * 100, 2)


cm = confusion_matrix(y_test, Y_prediction)
accuracy = accuracy_score(y_test,Y_prediction)
precision =precision_score(y_test, Y_prediction,average='micro')
recall =  recall_score(y_test, Y_prediction,average='micro')
f1 = f1_score(y_test,Y_prediction,average='micro')
print('Confusion matrix for Random Forest\n',cm)
print('accuracy_random_Forest : %.3f' %accuracy)
print('precision_random_Forest : %.3f' %precision)
print('recall_random_Forest : %.3f' %recall)
print('f1-score_random_Forest : %.3f' %f1)
# Out:
# Confusion matrix for Random Forest
#  [[11  0  0]
#  [ 0 14  3]
#  [ 0  0 17]]
# accuracy_random_Forest : 0.933
# precision_random_Forest : 0.933
# recall_random_Forest : 0.933
# f1-score_random_Forest : 0.933

# %%
import matplotlib.pyplot as plt
import itertools
from mlxtend.plotting import plot_decision_regions
fig = plt.figure(figsize=(10, 8))
labels = ['SVC']
RF_Classifier = RandomForestClassifier()
RF_Classifier.fit(X[:,[0,2]],y)
fig = plot_decision_regions(X=X[:,[0,2]], y=y,clf=RF_Classifier, legend=2)
plt.title(labels[0])

plt.show()

# %% [markdown]
# # ***Logistic Regression***

# %%
logreg = LogisticRegression(solver= 'lbfgs',max_iter=400)
logreg.fit(X_train, y_train)
Y_pred = logreg.predict(X_test)
accuracy_lr=round(accuracy_score(y_test,Y_pred)* 100, 2)
acc_log = round(logreg.score(X_train, y_train) * 100, 2)


cm = confusion_matrix(y_test, Y_pred,)
accuracy = accuracy_score(y_test,Y_pred)
precision =precision_score(y_test, Y_pred,average='micro')
recall =  recall_score(y_test, Y_pred,average='micro')
f1 = f1_score(y_test,Y_pred,average='micro')
print('Confusion matrix for Logistic Regression\n',cm)
print('accuracy_Logistic Regression : %.3f' %accuracy)
print('precision_Logistic Regression : %.3f' %precision)
print('recall_Logistic Regression: %.3f' %recall)
print('f1-score_Logistic Regression : %.3f' %f1)
# Out:
# Confusion matrix for Logistic Regression
#  [[11  0  0]
#  [ 0 15  2]
#  [ 0  0 17]]
# accuracy_Logistic Regression : 0.956
# precision_Logistic Regression : 0.956
# recall_Logistic Regression: 0.956
# f1-score_Logistic Regression : 0.956

# %%
import matplotlib.pyplot as plt
import itertools
from mlxtend.plotting import plot_decision_regions
fig = plt.figure(figsize=(10, 8))
labels = ['Logistic Regression']
LR_Classifier = LogisticRegression()
LR_Classifier.fit(X[:,[0,2]],y)
fig = plot_decision_regions(X=X[:,[0,2]], y=y,clf=LR_Classifier, legend=2)
plt.title(labels[0])

plt.show()

# %% [markdown]
# # *Which is the best Model ?*

# %%
import pandas as pd

results = pd.DataFrame({
    'Model': [ 'KNN',
              'Logistic Regression',
              'Random Forest',
              'Naive Bayes',
              ' Support Vector Machine',
              'Decision Tree'],
    'Score': [ acc_knn,
              acc_log,
              acc_random_forest,
              acc_gaussian,
              acc_linear_svc,
              acc_decision_tree],
    "Accuracy_score":[accuracy_knn,
                      accuracy_lr,
                      accuracy_rf,
                      accuracy_nb,
                      accuracy_svc,
                      accuracy_dt
                     ]})
result_df = results.sort_values(by='Accuracy_score', ascending=False)
result_df = result_df.reset_index(drop=True)
result_df
# Out:
#                      Model   Score  Accuracy_score
# 0      Logistic Regression   99.05           95.56
# 1                      KNN   99.05           93.33
# 2            Random Forest  100.00           93.33
# 3            Decision Tree  100.00           93.33
# 4              Naive Bayes   97.14           91.11
# 5   Support Vector Machine   97.14           91.11
